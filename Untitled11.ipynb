# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\cast.csv')

# %%
df.columns
# Out:
# Index(['title', 'year', 'name', 'type', 'character', 'n'], dtype='object')

# %%
df.shape
# Out:
# (75001, 6)

# %%
df.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %%
df1 =df[['title', 'year', 'name', 'type', 'character']]

# %%
df1
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character
# 0                      Buffy 4
# ...

# %%
df2 =df1[df1['name'] =='$hutter'].sort_index()

# %%
df2
# Out:
#                     title  year     name   type                character
# 2     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan
# 3    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan
# 4              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron
# 5  Straight Outta Compton  2015  $hutter  actor              Club Patron
# 6  Straight Outta Compton  2015  $hutter  actor                  Dopeman

# %%
df3 =df1[(df1['year']>=1985) & (df1['year'] <=2017)].sort_values('year', ascending = True)

# %%
df3
# Out:
#                                    title  year                     name  \
# 32137                    Barbarian Queen  1985      Alfredo Alesandrini
# 57788                         Oonche Log  1985               Salma Agha
# 57790                              Salma  1985               Salma Agha
# 37082             Otac na sluzbenom putu  1985       Slobodan Aligrudic
# 37073                  Indijsko ogledalo  1985       Slobodan Aligrudic
# ...                                  ...   ...                      ...
# 28934                        Rock'n Roll  2017             Xavier Alcan
# 69815                        Division 19  2017              Kerstin Alm
# 69817  Only Now Existing's Escape Artist  2017              Kerstin Alm
# 28804                     Barcelona 1714  2017                Toni Alb?
# 38854                   Welcome to Essex  2017  Christopher (XXX) Allen
#
#           type        character
# 32137    actor          Warrior
# 57788  actress     Poonam Singh
# ...

# %%
df.to_csv(r'C:\Users\HP\Desktop\sortedmoviessby_year.csv')

# %%
df['n'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 74996    False
# 74997     True
# 74998    False
# 74999     True
# 75000    False
# Name: n, Length: 75001, dtype: bool

# %%
nt =df[df['n'].isnull()].head()

# %%
nt
# Out:
#                     title  year          name   type                character  \
# 3    Secret in Their Eyes  2015       $hutter  actor          2002 Dodger Fan
# 4              Steve Jobs  2015       $hutter  actor  1988 Opera House Patron
# 5  Straight Outta Compton  2015       $hutter  actor              Club Patron
# 6  Straight Outta Compton  2015       $hutter  actor                  Dopeman
# 7          For Thy Love 2  2009  Bee Moe $lim  actor                   Thug 1
#
#     n
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN

# %%
nt[nt['title'] == 'Maa']
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %%
nt[nt['title'].str.startswith('S')]
# Out:
#                     title  year     name   type                character   n
# 3    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN
# 5  Straight Outta Compton  2015  $hutter  actor              Club Patron NaN
# 6  Straight Outta Compton  2015  $hutter  actor                  Dopeman NaN

# %%
NA =df[df['title'].isnull()].fillna('na')

# %%
NA
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %%
NA.head()
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []
