# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\cast.csv')

# %%
df.head(20)
# Out:
#                                                 title  year  \
# 0                                      Closet Monster  2015
# 1                                     Suuri illusioni  1985
# 2                                 Battle of the Sexes  2017
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 8   Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                        Desire (III)  2014
# 10                            When the Man Went South  2014
# 11                            Little Angel (Angelita)  2015
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
# 14                               All Out Dysfunktion!  2016
# ...

# %%
Na =df[df['n'].isnull()].fillna('NA')

# %%
Na.head(20)
# Out:
#                                                 title  year  \
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 9                                        Desire (III)  2014
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
# 14                               All Out Dysfunktion!  2016
# 15                                               Gook  2017
# 18                                       Hustle Beach  2017
# 20                                     Natas es Satan  1977
# 26                     The LXD: The Secrets of the Ra  2011
# 27                                        Todo x Sara  2014
# 28                                   Barrio Gangsters  2009
# ...

# %%
df['year'].value_counts().head(50)
# Out:
# 2016    3841
# 2015    3439
# 2014    3309
# 2013    3110
# 2012    3011
# 2011    2780
# 2010    2553
# 2009    2512
# 2008    2293
# 2017    2159
# 2007    1996
# 2006    1910
# 2005    1627
# 2004    1372
# 2002    1168
# 2003    1153
# 2001    1099
# 2000    1069
# 1999    1030
# 1997     929
# 1998     867
# 1995     783
# 1996     769
# 1994     691
# 1990     679
# 1989     659
# 1987     655
# 1988     655
# 1993     644
# 1991     637
# 1992     623
# 1985     620
# 1986     535
# 1984     531
# 1981     501
# 1982     487
# 1983     484
# 1974     478
# 1937     470
# 1969     459
# 1970     452
# 1953     448
# 1976     447
# 1942     447
# 1939     447
# 1941     444
# 1936     444
# 1975     438
# 1977     435
# 1940     435
# Name: year, dtype: int64

# %%
p =df['year'].value_counts().head(50)

# %%
p.sort_index().plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
c =df.groupby(['year']).size()

# %%
c.plot()
plt.xlabel('YEAR')
plt.ylabel('FREQUENCY')
plt.show()

# %%
c
# Out:
# year
# 1912       3
# 1913      10
# 1914      61
# 1915      82
# 1916     116
#         ...
# 2017    2159
# 2018     158
# 2019      16
# 2020       4
# 2023       3
# Length: 110, dtype: int64

# %%
name = df[df['name']== '$hutter'].sort_values('year', ascending=True)

# %%
name
# Out:
#                     title  year     name   type                character     n
# 3    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 4              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 5  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN
# 6  Straight Outta Compton  2015  $hutter  actor                  Dopeman   NaN
# 2     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0

# %%
name1 =df[df['name']=='$hutter']

# %%
name1.groupby(['year']).size()
# Out:
# year
# 2015    4
# 2017    1
# dtype: int64

# %%
name1.groupby(['year','title']).size()
# Out:
# year  title
# 2015  Secret in Their Eyes      1
#       Steve Jobs                1
#       Straight Outta Compton    2
# 2017  Battle of the Sexes       1
# dtype: int64

# %%
name1.groupby(['year','title']).n.min()
# Out:
# year  title
# 2015  Secret in Their Eyes       NaN
#       Steve Jobs                 NaN
#       Straight Outta Compton     NaN
# 2017  Battle of the Sexes       10.0
# Name: n, dtype: float64

# %%
name1.groupby(['year','title']).n.max()
# Out:
# year  title
# 2015  Secret in Their Eyes       NaN
#       Steve Jobs                 NaN
#       Straight Outta Compton     NaN
# 2017  Battle of the Sexes       10.0
# Name: n, dtype: float64

# %%
name1.groupby(['year']).n.mean()
# Out:
# year
# 2015     NaN
# 2017    10.0
# Name: n, dtype: float64

# %%
name1
# Out:
#                     title  year     name   type                character     n
# 2     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 3    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 4              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 5  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN
# 6  Straight Outta Compton  2015  $hutter  actor                  Dopeman   NaN
