# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\cast.csv')

# %%
df.head(20)
# Out:
#                                                 title  year  \
# 0                                      Closet Monster  2015
# 1                                     Suuri illusioni  1985
# 2                                 Battle of the Sexes  2017
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 8   Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                        Desire (III)  2014
# 10                            When the Man Went South  2014
# 11                            Little Angel (Angelita)  2015
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
# 14                               All Out Dysfunktion!  2016
# ...

# %%
new_df = df[df['name'] == '$hutter'].sort_index()

# %%
new_df
# Out:
#                     title  year     name   type                character     n
# 2     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 3    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 4              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 5  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN
# 6  Straight Outta Compton  2015  $hutter  actor                  Dopeman   NaN

# %%
new_df1 = df[df['name'] == "George 'Bootsy' Thomas"].sort_index()

# %%
new_df1
# Out:
#               title  year                    name   type          character  \
# 16  My Song for You  2010  George 'Bootsy' Thomas  actor  Cooley's Customer
# 17  My Song for You  2010  George 'Bootsy' Thomas  actor  Celebration Guest
#
#        n
# 16  16.0
# 17  16.0

# %%
Join = pd.concat([new_df,new_df1], axis =0)

# %%
Join
# Out:
#                      title  year                    name   type  \
# 2      Battle of the Sexes  2017                 $hutter  actor
# 3     Secret in Their Eyes  2015                 $hutter  actor
# 4               Steve Jobs  2015                 $hutter  actor
# 5   Straight Outta Compton  2015                 $hutter  actor
# 6   Straight Outta Compton  2015                 $hutter  actor
# 16         My Song for You  2010  George 'Bootsy' Thomas  actor
# 17         My Song for You  2010  George 'Bootsy' Thomas  actor
#
#                   character     n
# 2           Bobby Riggs Fan  10.0
# 3           2002 Dodger Fan   NaN
# 4   1988 Opera House Patron   NaN
# 5               Club Patron   NaN
# 6                   Dopeman   NaN
# 16        Cooley's Customer  16.0
# 17        Celebration Guest  16.0

# %%
join1 = new_df.merge(new_df1, on = 'n', how ='right')

# %%
join1
# Out:
#   title_x  year_x name_x type_x character_x     n          title_y  year_y  \
# 0     NaN     NaN    NaN    NaN         NaN  16.0  My Song for You    2010
# 1     NaN     NaN    NaN    NaN         NaN  16.0  My Song for You    2010
#
#                    name_y type_y        character_y
# 0  George 'Bootsy' Thomas  actor  Cooley's Customer
# 1  George 'Bootsy' Thomas  actor  Celebration Guest

# %%
df_new = pd.read_csv(r'C:\Users\HP\Desktop\cast.csv', index_col=None)

# %%
df_new
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
cm = df.set_index(['title', 'n', 'name']).sort_index()
cm.tail(30)
# Out:
#                                                                                  year  \
# title                                              n     name
# Zwei in einem Anzug                                2.0   Wolf Albach-Retty       1950
# Zwei in einem Auto                                 2.0   Wolf Albach-Retty       1951
# Zweimal zwei im Himmelbett                         1.0   Georg Alexander         1937
# Zwischen Lachen und Weinen                         NaN   Georg Alexander         1919
# Zwischen Pankow und Zehlendorf                     3.0   Kathrin Ackermann       1991
#                                                    NaN   Eugen Albert            1991
# Zwischen Welten                                    2.0   Mohsin Ahmady           2014
# Zwischen den Sternen                               2.0   Fatih Alas              2002
# Zwischen vierzehn und siebzehn - Sexualnot der ... 5.0   Fritz Alberti           1929
# ...

# %%
cm1 = cm.reset_index(['title', 'n', 'name']).sort_index()
cm1.head(30)
# Out:
#                                  title     n                 name  year  \
# 0                     #1 Serial Killer  17.0        Michael Alton  2013
# 1                  #DigitalLivesMatter   NaN           Rashan Ali  2016
# 2                        #FromJennifer   NaN         Aaron Abrams  2017
# 3                        #FromJennifer   NaN   Christian Ackerman  2017
# 4                              #Horror   1.0           Emma Adler  2015
# 5                        #Lucky Number  31.0         Grace Abbott  2015
# 6                   #Nerealnaya lyubov   NaN  Marina Aleksandrova  2014
# 7                         #REALITYHIGH   NaN      Suzanne Altfeld  2017
# 8                                #Roxy   NaN      Chris Aanderson  2017
# 9                               #Stuck  18.0         Logan Agayan  2014
# 10                              #Stuck   NaN         Gaby Alcazar  2014
# 11                              #Stuck   NaN         Gaby Alcazar  2014
# ...

# %%
dsk = df.get(['title', 'n', 'name']).sort_index()

# %%
dsk
# Out:
#                           title     n                        name
# 0                Closet Monster  31.0                    Buffy #1
# 1               Suuri illusioni  22.0                      Homo $
# 2           Battle of the Sexes  10.0                     $hutter
# 3          Secret in Their Eyes   NaN                     $hutter
# 4                    Steve Jobs   NaN                     $hutter
# ...                         ...   ...                         ...
# 74996  Mia fora kai ena... moro  11.0     Penelope Anastasopoulou
# 74997         The Magician King   NaN       Tiannah Anastassiades
# 74998        Festival of Lights  20.0             Zoe Anastassiou
# 74999                Toxic Tutu   NaN             Zoe Anastassiou
# 75000           Fugitive Pieces  25.0  Anastassia Anastassopoulou
#
# [75001 rows x 3 columns]
